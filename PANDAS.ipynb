# %%
print("Hello world")
# Out:
# Hello world

# %%
# PANDAS

# %%
# pandas is a opne source library that is use for handle data manipulation

# data structure of pandas
# 1. series --> series is one dimentional array and it is contains only vales not column name
# 2. Data Frame -->> data frame is multi-dimentional array . It is contain values and column name both

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# Series

a=pd.Series([1,23,45,75])
a
# Out:
# 0     1
# 1    23
# 2    45
# 3    75
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
# Data Frame

a = {
    "Emp_id": [1,2,3,4,5,6],
    "Name" : ["sam" , "raj" ,"nidhi" ,"raj" , "ridhi" ,"harah"] , 
    "department" : ["IT" ,"Sales" ,"IT" ,"networking" ,"Operation" ,"IT"],
    "Working" : [8,9,7,6,8,9]
}

# %%
df=pd.DataFrame(a)
df
# Out:
#    Emp_id   Name  department  Working
# 0       1    sam          IT        8
# 1       2    raj       Sales        9
# 2       3  nidhi          IT        7
# 3       4    raj  networking        6
# 4       5  ridhi   Operation        8
# 5       6  harah          IT        9

# %%
type(a)
# Out:
# dict

# %%
# how we can import or export our dataframe

df.to_csv("C:\\Users\\ace\\Downloads\\covid_toy.csv" , index=False)

# %%
df=pd.read_csv("C:\\Users\\ace\\Downloads\\covid_toy (1).csv")

# %%
df
# Out:
#    Unnamed: 0  Emp_id   Name  department  Working
# 0           0       1    sam          IT        8
# 1           1       2    raj       Sales        9
# 2           2       3  nidhi          IT        7
# 3           3       4    raj  networking        6
# 4           4       5  ridhi   Operation        8
# 5           5       6  harah          IT        9

# %%
df1=pd.read_csv("Employee_data_50.csv")
df1
# Out:
#     Unnamed: 0  EmployeeID           Name Department JoiningDate  Age  Salary  \
# 0            0         101    Nina Walker    Finance  2018-09-10   36   87065
# 1            1         102   Rachel Lewis         HR  2019-08-09   47  142093
# 2            2         103      Bob Smith         IT  2012-05-10   44  149299
# 3            3         104  Charlie Brown         HR  2013-07-18   49   82606
# 4            4         105    Paul Turner         HR  2013-02-04   27   61534
# 5            5         106      Ian Clark    Finance  2012-12-31   29  144663
# 6            6         107      David Lee         HR  2018-06-20   43   90397
# 7            7         108  Alice Johnson         HR  2014-06-27   31  141387
# 8            8         109      David Lee    Finance  2015-12-10   45   51016
# 9            9         110  Alice Johnson         HR  2011-04-12   33  139789
# 10          10         111    Nina Walker         HR  2013-05-23   31  105591
# ...

# %%
# how can we cheque top datas


df.head()
# Out:
#    Unnamed: 0  Emp_id   Name  department  Working
# 0           0       1    sam          IT        8
# 1           1       2    raj       Sales        9
# 2           2       3  nidhi          IT        7
# 3           3       4    raj  networking        6
# 4           4       5  ridhi   Operation        8

# %%
# how can we cheque bottom datas

df.tail()
# Out:
#    Unnamed: 0  Emp_id   Name  department  Working
# 1           1       2    raj       Sales        9
# 2           2       3  nidhi          IT        7
# 3           3       4    raj  networking        6
# 4           4       5  ridhi   Operation        8
# 5           5       6  harah          IT        9

# %%
# how can we cheque and random datas

df.sample(5)
# Out:
#    Unnamed: 0  Emp_id   Name  department  Working
# 1           1       2    raj       Sales        9
# 3           3       4    raj  networking        6
# 0           0       1    sam          IT        8
# 2           2       3  nidhi          IT        7
# 5           5       6  harah          IT        9

# %%
# how can we cheque total shape of data?
df.shape
# Out:
# (6, 5)

# %%
# how can we cheque total columns in dataframe

df.columns
# Out:
# Index(['Unnamed: 0', 'Emp_id', 'Name', 'department', 'Working'], dtype='object')

# %%
# you have to updata "raj" to "kamal" and change its working ours also
df['Name']
# Out:
# 0      sam
# 1      raj
# 2    nidhi
# 3      raj
# 4    ridhi
# 5    harah
# Name: Name, dtype: object

# %%
df['Name'][1]='kamal'
# Out:
# C:\Users\ace\AppData\Local\Temp\ipykernel_11640\665080780.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name'][1]='kamal'

# %%
df
# Out:
#    Unnamed: 0  Emp_id   Name  department  Working
# 0           0       1    sam          IT        8
# 1           1       2  kamal       Sales        9
# 2           2       3  nidhi          IT        7
# 3           3       4    raj  networking        6
# 4           4       5  ridhi   Operation        8
# 5           5       6  harah          IT        9

# %%
df['Working'][0] = 12
# Out:
# C:\Users\ace\AppData\Local\Temp\ipykernel_11640\2249106208.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['Working'][0] = 12
# ...

# %%
df
# Out:
#    Unnamed: 0  Emp_id   Name  department  Working
# 0           0       1    sam          IT       12
# 1           1       2  kamal       Sales        9
# 2           2       3  nidhi          IT        7
# 3           3       4    raj  networking        6
# 4           4       5  ridhi   Operation        8
# 5           5       6  harah          IT        9

# %%
# how can we cheque total_sub_categories frequency of a columns

df['Name'].value_counts()
# Out:
# Name
# sam      1
# kamal    1
# nidhi    1
# raj      1
# ridhi    1
# harah    1
# Name: count, dtype: int64

# %%
df['department'].value_counts()
# Out:
# department
# IT            3
# Sales         1
# networking    1
# Operation     1
# Name: count, dtype: int64

# %%
# how can we handle missing data?
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Emp_id        0
# Name          0
# department    0
# Working       0
# dtype: int64

# %%
df
# Out:
#    Unnamed: 0  Emp_id   Name  department  Working
# 0           0       1    sam          IT       12
# 1           1       2  kamal       Sales        9
# 2           2       3  nidhi          IT        7
# 3           3       4    raj  networking        6
# 4           4       5  ridhi   Operation        8
# 5           5       6  harah          IT        9

# %%
df['Name'][1]=None
df['department'][3]=None
# Out:
# C:\Users\ace\AppData\Local\Temp\ipykernel_11640\218491767.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name'][1]=None
# C:\Users\ace\AppData\Local\Temp\ipykernel_11640\218491767.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# ...

# %%
df
# Out:
#    Unnamed: 0  Emp_id   Name department  Working
# 0           0       1    sam         IT       12
# 1           1       2   None      Sales        9
# 2           2       3  nidhi         IT        7
# 3           3       4    raj       None        6
# 4           4       5  ridhi  Operation        8
# 5           5       6  harah         IT        9

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Emp_id        0
# Name          1
# department    1
# Working       0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# Emp_id        0
# Name          0
# department    0
# Working       0
# dtype: int64

# %%
df
# Out:
#    Unnamed: 0  Emp_id   Name department  Working
# 0           0       1    sam         IT       12
# 2           2       3  nidhi         IT        7
# 4           4       5  ridhi  Operation        8
# 5           5       6  harah         IT        9

# %%
# assignment

# create a data frame about ->
# Student Information
# Student_id
# Course_name
# Course_duration
# Fees

# and apply these alll conditions

# data import and export 
# head() , tail() , sample()
# create missing data ,, handle missing data
# values_counts()

# %%
std={
    "Student_id":[1,2,3,4,5,6,7],
    "Course":["data science" ,"data analytics" ,"java" ,"science","data science",None ,"data analytics"],
    'course duration':[10,8,6,4,10, None , 8],
    "fees":[50 , 40 ,30 ,10, 50, None, 40 ]
    
}

# %%
df=pd.DataFrame(std)
df
# Out:
#    Student_id          Course  course duration  fees
# 0           1    data science             10.0  50.0
# 1           2  data analytics              8.0  40.0
# 2           3            java              6.0  30.0
# 3           4         science              4.0  10.0
# 4           5    data science             10.0  50.0
# 5           6            None              NaN   NaN
# 6           7  data analytics              8.0  40.0

# %%
df.head(5)
# Out:
#    Student_id          Course  course duration  fees
# 0           1    data science             10.0  50.0
# 1           2  data analytics              8.0  40.0
# 2           3            java              6.0  30.0
# 3           4         science              4.0  10.0
# 4           5    data science             10.0  50.0

# %%
df.tail(5)
# Out:
#    Student_id          Course  course duration  fees
# 2           3            java              6.0  30.0
# 3           4         science              4.0  10.0
# 4           5    data science             10.0  50.0
# 5           6            None              NaN   NaN
# 6           7  data analytics              8.0  40.0

# %%
df.sample(5)
# Out:
#    Student_id          Course  course duration  fees
# 5           6            None              NaN   NaN
# 1           2  data analytics              8.0  40.0
# 4           5    data science             10.0  50.0
# 3           4         science              4.0  10.0
# 2           3            java              6.0  30.0

# %%
df.isnull().sum()
# Out:
# Student_id         0
# Course             1
# course duration    1
# fees               1
# dtype: int64

# %%
df["Course"].value_counts()
# Out:
# Course
# data science      2
# data analytics    2
# java              1
# science           1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Student_id         0
# Course             1
# course duration    1
# fees               1
# dtype: int64

# %%
df.dropna()
# Out:
#    Student_id          Course  course duration  fees
# 0           1    data science             10.0  50.0
# 1           2  data analytics              8.0  40.0
# 2           3            java              6.0  30.0
# 3           4         science              4.0  10.0
# 4           5    data science             10.0  50.0
# 6           7  data analytics              8.0  40.0

# %%
df
# Out:
#    Student_id          Course  course duration  fees
# 0           1    data science             10.0  50.0
# 1           2  data analytics              8.0  40.0
# 2           3            java              6.0  30.0
# 3           4         science              4.0  10.0
# 4           5    data science             10.0  50.0
# 5           6            None              NaN   NaN
# 6           7  data analytics              8.0  40.0
